# %% [markdown]
# # How to import dataset in python

# %%
#step1
#importing lib
import pandas as pd

# %%
#step2
#reading/importing dataset
df=pd.read_excel("pandas_01_day6.xlsx")

# %%
df
# Out:
#     height  weight favourite_dish
# 0      5.8     101  Chicken Pulao
# 1      6.2      92        Biryani
# 2      5.9      62  Karahi Ghosht
# 3      5.9      95  Chicken Pulao
# 4      5.9      55  Chicken Pulao
# ..     ...     ...            ...
# 82     5.4      55          Pasta
# 83     5.9      75  Karahi Ghosht
# 84     5.4      61        Biryani
# 85     6.2      68  Chicken Pulao
# 86     5.1      96        Biryani
#
# [87 rows x 3 columns]

# %%
df.head()
# Out:
#    height  weight favourite_dish
# 0     5.8     101  Chicken Pulao
# 1     6.2      92        Biryani
# 2     5.9      62  Karahi Ghosht
# 3     5.9      95  Chicken Pulao
# 4     5.9      55  Chicken Pulao

# %%
df.tail()
# Out:
#     height  weight favourite_dish
# 82     5.4      55          Pasta
# 83     5.9      75  Karahi Ghosht
# 84     5.4      61        Biryani
# 85     6.2      68  Chicken Pulao
# 86     5.1      96        Biryani

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87 entries, 0 to 86
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   height          87 non-null     float64
#  1   weight          87 non-null     int64
#  2   favourite_dish  87 non-null     object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 2.2+ KB

# %%
df["height"]=df["height"].replace(167.0,5.7)

# %%
df.sort_values(by="height",ascending=False)
# Out:
#     height  weight favourite_dish
# 85     6.2      68  Chicken Pulao
# 1      6.2      92        Biryani
# 12     6.1      78        Biryani
# 60     6.0      88        Biryani
# 25     6.0      50        Biryani
# ..     ...     ...            ...
# 86     5.1      96        Biryani
# 15     5.0      57        Biryani
# 40     5.0      50  Chicken Pulao
# 35     5.0      31        Biryani
# 26     5.0      25        Biryani
#
# [87 rows x 3 columns]

# %%
df.describe()
# Out:
#           height      weight
# count  87.000000   87.000000
# mean    5.555862   70.459770
# std     0.331331   16.753899
# min     5.000000   25.000000
# 25%     5.300000   60.000000
# 50%     5.600000   70.000000
# 75%     5.800000   80.000000
# max     6.200000  125.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87 entries, 0 to 86
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   height          87 non-null     float64
#  1   weight          87 non-null     int64
#  2   favourite_dish  87 non-null     object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 2.2+ KB

# %%
df["height"]=(df["height"].astype(float))

# %%
import pandas as pd
import numpy as np
import seaborn as sns
df=sns.load_dataset("titanic")
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
count=df.age.value_counts()
count.nlargest()
# Out:
# age
# 24.0    30
# 22.0    27
# 18.0    26
# 19.0    25
# 28.0    25
# Name: count, dtype: int64

# %% [markdown]
# #16. SPLIT A STRING INTO MULTIPLE COLUMNS

# %%
df=pd.DataFrame({'name':["Aiman Aali","Mohammad Mehdi", "Najam-us Saqib"],
                 "location":["Qatar,Doha","Pakistan,Talagang","Paksitan,Talagang1"]
})
df
# Out:
#              name            location
# 0      Aiman Aali          Qatar,Doha
# 1  Mohammad Mehdi   Pakistan,Talagang
# 2  Najam-us Saqib  Paksitan,Talagang1

# %%
df[["First_Name","Last_Name"]]=df.name.str.split(" ",expand=True)
df
# Out:
#              name            location First_Name Last_Name
# 0      Aiman Aali          Qatar,Doha      Aiman      Aali
# 1  Mohammad Mehdi   Pakistan,Talagang   Mohammad     Mehdi
# 2  Najam-us Saqib  Paksitan,Talagang1   Najam-us     Saqib

# %%
df["hello"]=[1,2,3]
df
# Out:
#              name            location First_Name Last_Name  hello
# 0      Aiman Aali          Qatar,Doha      Aiman      Aali      1
# 1  Mohammad Mehdi   Pakistan,Talagang   Mohammad     Mehdi      2
# 2  Najam-us Saqib  Paksitan,Talagang1   Najam-us     Saqib      3

# %%
df[["county","city"]]=df.location.str.split(",",expand=True)
df
# Out:
#              name            location First_Name Last_Name  hello    county  \
# 0      Aiman Aali          Qatar,Doha      Aiman      Aali      1     Qatar
# 1  Mohammad Mehdi   Pakistan,Talagang   Mohammad     Mehdi      2  Pakistan
# 2  Najam-us Saqib  Paksitan,Talagang1   Najam-us     Saqib      3  Paksitan
#
#         city
# 0       Doha
# 1   Talagang
# 2  Talagang1

# %% [markdown]
# #NOW REFINE DATA MANIPULATION

# %%
df=df[['First_Name', 'Last_Name','county',
       'city']]
df
# Out:
#   First_Name Last_Name    county       city
# 0      Aiman      Aali     Qatar       Doha
# 1   Mohammad     Mehdi  Pakistan   Talagang
# 2   Najam-us     Saqib  Paksitan  Talagang1

# %% [markdown]
# #HOW TO AGGREGATE BY MULTIGROUP/FUNCTIONS:

# %%
#Import libraries
import pandas as pd
import numpy as np
import seaborn as sns
df=sns. load_dataset('titanic')
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.describe().loc['min':'max',['survived','age']]
# Out:
#      survived     age
# min       0.0   0.420
# 25%       0.0  20.125
# 50%       0.0  28.000
# 75%       1.0  38.000
# max       1.0  80.000

# %% [markdown]
# # RESHAPE MULTIINDEX SERIES:

# %%
df.survived.mean()
df.groupby(['sex']).survived.mean()
# Out:
# sex
# female    0.742038
# male      0.188908
# Name: survived, dtype: float64

# %%
df.groupby(['sex','pclass']).survived.mean()
# Out:
# sex     pclass
# female  1         0.968085
#         2         0.921053
#         3         0.500000
# male    1         0.368852
#         2         0.157407
#         3         0.135447
# Name: survived, dtype: float64

# %%
df.groupby(['sex','pclass']).survived.mean().unstack()
# Out:
# pclass         1         2         3
# sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %% [markdown]
# # __CONTINOUS TO CATOGORICAL DATA CONVERSION__

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df["new_age"]=pd.cut(df.age ,bins=[0,18,25,99],labels=['child','young_adult','adult'])
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone      new_age
# 0    man        True  NaN  Southampton    no  False  young_adult
# 1  woman       False    C    Cherbourg   yes  False        adult
# 2  woman       False  NaN  Southampton   yes   True        adult
# 3  woman       False    C  Southampton   yes  False        adult
# 4    man        True  NaN  Southampton    no   True        adult

# %%
df.groupby('new_age').sex.count()
# Out:
# C:\Users\AIMAN\AppData\Local\Temp\ipykernel_2896\3047059786.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('new_age').sex.count()
# new_age
# child          139
# young_adult    162
# adult          413
# Name: sex, dtype: int64

# %%
df["sex_num"]=df.sex.map({"male":0, "female":1})
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone      new_age  sex_num
# 0    man        True  NaN  Southampton    no  False  young_adult        0
# 1  woman       False    C    Cherbourg   yes  False        adult        1
# 2  woman       False  NaN  Southampton   yes   True        adult        1
# 3  woman       False    C  Southampton   yes  False        adult        1
# 4    man        True  NaN  Southampton    no   True        adult        0

# %%
df["embarked_num"]=df.embarked.factorize()[0]
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone      new_age  sex_num  \
# 0    man        True  NaN  Southampton    no  False  young_adult        0
# 1  woman       False    C    Cherbourg   yes  False        adult        1
# 2  woman       False  NaN  Southampton   yes   True        adult        1
# 3  woman       False    C  Southampton   yes  False        adult        1
# 4    man        True  NaN  Southampton    no   True        adult        0
#
#    embarked_num
# 0             0
# 1             1
# 2             0
# 3             0
# 4             0

# %% [markdown]
# # TRANSPOSE A WIDE DATAFRAME

# %%
import numpy as np
import pandas as pd
arr =np.random.rand(200,25)
arr
df=pd.DataFrame(np.random.rand(200,25),columns=list('abcdefghijklmnopqrstuvwxy'))
df.head()
# Out:
#           a         b         c         d         e         f         g  \
# 0  0.091808  0.215189  0.333336  0.396419  0.777244  0.145667  0.550576
# 1  0.319769  0.717522  0.964701  0.890878  0.849212  0.725498  0.532237
# 2  0.477131  0.704017  0.461737  0.567994  0.938434  0.171085  0.954044
# 3  0.093410  0.826654  0.840542  0.015236  0.633171  0.994323  0.215339
# 4  0.133267  0.349551  0.314639  0.940523  0.788551  0.424676  0.695407
#
#           h         i         j  ...         p         q         r         s  \
# 0  0.787446  0.791524  0.712560  ...  0.889062  0.447357  0.973682  0.541013
# 1  0.166333  0.503049  0.622517  ...  0.671330  0.522058  0.922267  0.230842
# 2  0.606477  0.291369  0.748048  ...  0.223912  0.131800  0.033894  0.489502
# 3  0.620559  0.886032  0.014465  ...  0.891281  0.391508  0.586422  0.678133
# 4  0.478808  0.839692  0.596479  ...  0.810841  0.935039  0.210966  0.938034
#
#           t         u         v         w         x         y
# 0  0.955963  0.905643  0.236498  0.822131  0.986076  0.741076
# 1  0.007399  0.283920  0.243963  0.899122  0.046326  0.087918
# 2  0.580616  0.791539  0.837745  0.958555  0.685179  0.485079
# 3  0.399439  0.909730  0.700539  0.804570  0.066759  0.709208
# 4  0.984099  0.182817  0.711378  0.525529  0.466795  0.320467
#
# [5 rows x 25 columns]

# %%
df.describe().T.to_excel('random_data_to_excel.xlsx')

# %%
pd.read_excel('random_data_to_excel.xlsx')
# Out:
#    Unnamed: 0  count      mean       std       min       25%       50%  \
# 0           a    200  0.514234  0.276852  0.000329  0.273935  0.494987
# 1           b    200  0.480758  0.289710  0.010858  0.219658  0.474199
# 2           c    200  0.475725  0.295778  0.001385  0.201071  0.459269
# 3           d    200  0.506236  0.299083  0.003073  0.248747  0.527978
# 4           e    200  0.499103  0.299377  0.001486  0.257666  0.483119
# 5           f    200  0.517019  0.292624  0.002311  0.270776  0.531943
# 6           g    200  0.492848  0.277186  0.002167  0.260141  0.492346
# 7           h    200  0.502183  0.280737  0.009185  0.290366  0.489924
# 8           i    200  0.530429  0.285246  0.003375  0.296101  0.528814
# 9           j    200  0.520690  0.282738  0.004122  0.294193  0.556190
# 10          k    200  0.479840  0.280252  0.003789  0.234717  0.488909
# 11          l    200  0.508448  0.287735  0.002023  0.253458  0.532157
# 12          m    200  0.495413  0.299325  0.000212  0.228287  0.521633
# 13          n    200  0.501900  0.297486  0.003197  0.260447  0.469459
# 14          o    200  0.512231  0.285782  0.010137  0.262070  0.526178
# 15          p    200  0.556301  0.289976  0.003987  0.315316  0.573207
# 16          q    200  0.478078  0.270827  0.010851  0.252613  0.466590
# 17          r    200  0.481607  0.270031  0.003409  0.240283  0.472134
# 18          s    200  0.512425  0.288727  0.000239  0.267371  0.493788
# 19          t    200  0.487919  0.288878  0.004446  0.235903  0.509412
# 20          u    200  0.526953  0.289676  0.004740  0.281607  0.523838
# 21          v    200  0.515832  0.294937  0.004338  0.255726  0.543868
# 22          w    200  0.511658  0.289743  0.000178  0.278536  0.497601
# 23          x    200  0.481165  0.293400  0.014639  0.231001  0.475718
# 24          y    200  0.508285  0.303715  0.002749  0.246133  0.493494
#
#          75%       max
# 0   0.767501  0.984802
# 1   0.715552  0.996143
# 2   0.712252  0.998365
# 3   0.771948  0.994459
# 4   0.744016  0.997631
# 5   0.797530  0.999241
# 6   0.707453  0.999022
# 7   0.751657  0.994000
# 8   0.788052  0.998952
# 9   0.765285  0.996175
# 10  0.706496  0.996773
# 11  0.766098  0.986037
# 12  0.760214  0.991877
# 13  0.769605  0.986640
# 14  0.766475  0.998147
# 15  0.800501  0.997913
# 16  0.702289  0.989184
# 17  0.684547  0.994749
# 18  0.760110  0.997573
# 19  0.735813  0.995717
# 20  0.788882  0.998992
# 21  0.778103  0.999500
# 22  0.765546  0.999522
# 23  0.711942  0.995990
# 24  0.786690  0.998425

# %% [markdown]
# # RESHAPING A DATAFRAME

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
fasla= pd.DataFrame([["00000",100,200,300],["11111",400,500,600],["22222",700,800,900]],columns=["zip_code","factory","warehouse", "retail"])
print(fasla.head())
print(fasla.columns)
# Out:
#   zip_code  factory  warehouse  retail
# 0    00000      100        200     300
# 1    11111      400        500     600
# 2    22222      700        800     900
# Index(['zip_code', 'factory', 'warehouse', 'retail'], dtype='object')

# %%
melted_fasla=fasla.melt(id_vars="zip_code",value_name='distance',var_name='location')
melted_fasla
# Out:
#   zip_code   location  distance
# 0    00000    factory       100
# 1    11111    factory       400
# 2    22222    factory       700
# 3    00000  warehouse       200
# 4    11111  warehouse       500
# 5    22222  warehouse       800
# 6    00000     retail       300
# 7    11111     retail       600
# 8    22222     retail       900

# %%
sns.barplot(x="zip_code", y="distance", hue="location",data=melted_fasla)
# Out:
# <Axes: xlabel='zip_code', ylabel='distance'>

# %%
phool=sns.load_dataset("iris")
phool.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
phool.to_excel('../day_2/phool1.xlsx')

# %%
df=sns.load_dataset("titanic")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
df.describe().T
# Out:
#           count       mean        std   min      25%      50%   75%       max
# survived  891.0   0.383838   0.486592  0.00   0.0000   0.0000   1.0    1.0000
# pclass    891.0   2.308642   0.836071  1.00   2.0000   3.0000   3.0    3.0000
# age       714.0  29.699118  14.526497  0.42  20.1250  28.0000  38.0   80.0000
# sibsp     891.0   0.523008   1.102743  0.00   0.0000   0.0000   1.0    8.0000
# parch     891.0   0.381594   0.806057  0.00   0.0000   0.0000   0.0    6.0000
# fare      891.0  32.204208  49.693429  0.00   7.9104  14.4542  31.0  512.3292

# %%
df["survived"].describe()
# Out:
# count    891.000000
# mean       0.383838
# std        0.486592
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# Name: survived, dtype: float64

# %%
df.groupby(["sex","survived","who","pclass"])["survived"].count()
# Out:
# sex     survived  who    pclass
# female  0         child  1           1
#                          3          14
#                   woman  1           2
#                          2           6
#                          3          58
#         1         child  1           2
#                          2          10
#                          3          16
#                   woman  1          89
#                          2          60
#                          3          56
# male    0         child  3          19
#                   man    1          77
#                          2          91
#                          3         281
#         1         child  1           3
#                          2           9
#                          3           9
#                   man    1          42
#                          2           8
#                          3          38
# Name: survived, dtype: int64

# %%
sns.countplot(x="survived", hue="sex", data=df)
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
sns.boxplot(x="sex",y="survived" ,data=df)
# Out:
# <Axes: xlabel='sex', ylabel='survived'>

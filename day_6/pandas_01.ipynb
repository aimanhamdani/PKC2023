# %% [markdown]
# # How to import dataset in python

# %%
#step1
#importing lib
import pandas as pd

# %%
#step2
#reading/importing dataset
df=pd.read_excel("pandas_01_day6.xlsx")

# %%
df9=pd.read_excel("../day_2/phool1.xlsx")
df9.to_csv("../day_1/phool_of_df9.csv")

# %%
df.head()
# Out:
#    height  weight favourite_dish
# 0     5.8     101  Chicken Pulao
# 1     6.2      92        Biryani
# 2     5.9      62  Karahi Ghosht
# 3     5.9      95  Chicken Pulao
# 4     5.9      55  Chicken Pulao

# %%
df.tail()
# Out:
#     height  weight favourite_dish
# 82     5.4      55          Pasta
# 83     5.9      75  Karahi Ghosht
# 84     5.4      61        Biryani
# 85     6.2      68  Chicken Pulao
# 86     5.1      96        Biryani

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87 entries, 0 to 86
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   height          87 non-null     float64
#  1   weight          87 non-null     int64
#  2   favourite_dish  87 non-null     object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 2.2+ KB

# %%
df["height"]=df["height"].replace(167.0,5.7)

# %%
df.sort_values(by="height",ascending=False)
# Out:
#     height  weight favourite_dish
# 85     6.2      68  Chicken Pulao
# 1      6.2      92        Biryani
# 12     6.1      78        Biryani
# 60     6.0      88        Biryani
# 25     6.0      50        Biryani
# ..     ...     ...            ...
# 86     5.1      96        Biryani
# 15     5.0      57        Biryani
# 40     5.0      50  Chicken Pulao
# 35     5.0      31        Biryani
# 26     5.0      25        Biryani
#
# [87 rows x 3 columns]

# %%
df.describe()
# Out:
#           height      weight
# count  87.000000   87.000000
# mean    5.555862   70.459770
# std     0.331331   16.753899
# min     5.000000   25.000000
# 25%     5.300000   60.000000
# 50%     5.600000   70.000000
# 75%     5.800000   80.000000
# max     6.200000  125.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87 entries, 0 to 86
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   height          87 non-null     float64
#  1   weight          87 non-null     int64
#  2   favourite_dish  87 non-null     object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 2.2+ KB

# %%
df["height"]=(df["height"].astype(float))

# %%
import pandas as pd
import numpy as np
import seaborn as sns
df=sns.load_dataset("titanic")
df.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
count=df.age.value_counts()
count.nlargest()
# Out:
# age
# 24.0    30
# 22.0    27
# 18.0    26
# 19.0    25
# 28.0    25
# Name: count, dtype: int64

# %% [markdown]
# #16. SPLIT A STRING INTO MULTIPLE COLUMNS

# %%
df=pd.DataFrame({'name':["Aiman Aali","Mohammad Mehdi", "Najam-us Saqib"],
                 "location":["Qatar,Doha","Pakistan,Talagang","Paksitan,Talagang1"]
})
df
# Out:
#              name            location
# 0      Aiman Aali          Qatar,Doha
# 1  Mohammad Mehdi   Pakistan,Talagang
# 2  Najam-us Saqib  Paksitan,Talagang1

# %%
df[["First_Name","Last_Name"]]=df.name.str.split(" ",expand=True)
df
# Out:
#              name            location First_Name Last_Name
# 0      Aiman Aali          Qatar,Doha      Aiman      Aali
# 1  Mohammad Mehdi   Pakistan,Talagang   Mohammad     Mehdi
# 2  Najam-us Saqib  Paksitan,Talagang1   Najam-us     Saqib

# %%
df["hello"]=[1,2,3]
df
# Out:
#              name            location First_Name Last_Name  hello
# 0      Aiman Aali          Qatar,Doha      Aiman      Aali      1
# 1  Mohammad Mehdi   Pakistan,Talagang   Mohammad     Mehdi      2
# 2  Najam-us Saqib  Paksitan,Talagang1   Najam-us     Saqib      3

# %%
df[["county","city"]]=df.location.str.split(",",expand=True)
df
# Out:
#              name            location First_Name Last_Name  hello    county  \
# 0      Aiman Aali          Qatar,Doha      Aiman      Aali      1     Qatar
# 1  Mohammad Mehdi   Pakistan,Talagang   Mohammad     Mehdi      2  Pakistan
# 2  Najam-us Saqib  Paksitan,Talagang1   Najam-us     Saqib      3  Paksitan
#
#         city
# 0       Doha
# 1   Talagang
# 2  Talagang1

# %% [markdown]
# #NOW REFINE DATA MANIPULATION

# %%
df=df[['First_Name', 'Last_Name','county',
       'city']]
df
# Out:
#   First_Name Last_Name    county       city
# 0      Aiman      Aali     Qatar       Doha
# 1   Mohammad     Mehdi  Pakistan   Talagang
# 2   Najam-us     Saqib  Paksitan  Talagang1

# %% [markdown]
# #HOW TO AGGREGATE BY MULTIGROUP/FUNCTIONS:

# %%
#Import libraries
import pandas as pd
import numpy as np
import seaborn as sns
df=sns. load_dataset('titanic')
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.describe().loc['min':'max',['survived','age']]
# Out:
#      survived     age
# min       0.0   0.420
# 25%       0.0  20.125
# 50%       0.0  28.000
# 75%       1.0  38.000
# max       1.0  80.000

# %% [markdown]
# # RESHAPE MULTIINDEX SERIES:

# %%
df.survived.mean()
df.groupby(['sex']).survived.mean()
# Out:
# sex
# female    0.742038
# male      0.188908
# Name: survived, dtype: float64

# %%
df.groupby(['sex','pclass']).survived.mean()
# Out:
# sex     pclass
# female  1         0.968085
#         2         0.921053
#         3         0.500000
# male    1         0.368852
#         2         0.157407
#         3         0.135447
# Name: survived, dtype: float64

# %%
df.groupby(['sex','pclass']).survived.mean().unstack()
# Out:
# pclass         1         2         3
# sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %% [markdown]
# # __CONTINOUS TO CATOGORICAL DATA CONVERSION__

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df["new_age"]=pd.cut(df.age ,bins=[0,18,25,99],labels=['child','young_adult','adult'])
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone      new_age
# 0    man        True  NaN  Southampton    no  False  young_adult
# 1  woman       False    C    Cherbourg   yes  False        adult
# 2  woman       False  NaN  Southampton   yes   True        adult
# 3  woman       False    C  Southampton   yes  False        adult
# 4    man        True  NaN  Southampton    no   True        adult

# %%
df.groupby('new_age').sex.count()
# Out:
# C:\Users\AIMAN\AppData\Local\Temp\ipykernel_5412\3047059786.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('new_age').sex.count()
# new_age
# child          139
# young_adult    162
# adult          413
# Name: sex, dtype: int64

# %%
df["sex_num"]=df.sex.map({"male":0, "female":1})
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone      new_age  sex_num
# 0    man        True  NaN  Southampton    no  False  young_adult        0
# 1  woman       False    C    Cherbourg   yes  False        adult        1
# 2  woman       False  NaN  Southampton   yes   True        adult        1
# 3  woman       False    C  Southampton   yes  False        adult        1
# 4    man        True  NaN  Southampton    no   True        adult        0

# %%
df["embarked_num"]=df.embarked.factorize()[0]
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone      new_age  sex_num  \
# 0    man        True  NaN  Southampton    no  False  young_adult        0
# 1  woman       False    C    Cherbourg   yes  False        adult        1
# 2  woman       False  NaN  Southampton   yes   True        adult        1
# 3  woman       False    C  Southampton   yes  False        adult        1
# 4    man        True  NaN  Southampton    no   True        adult        0
#
#    embarked_num
# 0             0
# 1             1
# 2             0
# ...

# %% [markdown]
# # TRANSPOSE A WIDE DATAFRAME

# %%
import numpy as np
import pandas as pd
arr =np.random.rand(200,25)
arr
df=pd.DataFrame(np.random.rand(200,25),columns=list('abcdefghijklmnopqrstuvwxy'))
df.head()
# Out:
#           a         b         c         d         e         f         g  \
# 0  0.075839  0.539545  0.314668  0.091607  0.199483  0.920219  0.477467
# 1  0.025693  0.804136  0.670370  0.734621  0.862829  0.679889  0.144362
# 2  0.518179  0.602696  0.882265  0.873271  0.706312  0.408391  0.827078
# 3  0.518416  0.218045  0.971960  0.679196  0.465540  0.582190  0.844215
# 4  0.118949  0.835927  0.816573  0.134326  0.462697  0.384850  0.789081
#
#           h         i         j  ...         p         q         r         s  \
# 0  0.324903  0.388412  0.966155  ...  0.868777  0.731388  0.723395  0.377400
# 1  0.161615  0.962501  0.713245  ...  0.871595  0.077298  0.990986  0.056659
# 2  0.637442  0.928093  0.857778  ...  0.735022  0.142162  0.487983  0.040628
# 3  0.282730  0.558912  0.076313  ...  0.626258  0.334086  0.361115  0.132038
# 4  0.728022  0.026258  0.365674  ...  0.242789  0.931014  0.228284  0.242758
#
#           t         u         v         w         x         y
# ...

# %%
df.describe().T.to_excel('random_data_to_excel.xlsx')

# %%
pd.read_excel('random_data_to_excel.xlsx')
# Out:
#    Unnamed: 0  count      mean       std       min       25%       50%  \
# 0           a    200  0.513143  0.286878  0.004363  0.292645  0.500407
# 1           b    200  0.489881  0.276236  0.001904  0.247900  0.507878
# 2           c    200  0.578583  0.269729  0.001443  0.385875  0.622418
# 3           d    200  0.485338  0.290322  0.006457  0.242269  0.482490
# 4           e    200  0.509644  0.280150  0.005403  0.305620  0.527927
# 5           f    200  0.510486  0.295336  0.002437  0.292334  0.469988
# 6           g    200  0.540539  0.279993  0.006721  0.285634  0.572890
# 7           h    200  0.538749  0.294661  0.006424  0.287245  0.556285
# 8           i    200  0.525846  0.271643  0.001440  0.303714  0.531466
# 9           j    200  0.521306  0.295882  0.000109  0.272375  0.533844
# 10          k    200  0.470493  0.287372  0.005662  0.216759  0.449782
# 11          l    200  0.502019  0.308060  0.000643  0.229332  0.476615
# ...

# %% [markdown]
# # RESHAPING A DATAFRAME

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
fasla= pd.DataFrame([["00000",100,200,300],["11111",400,500,600],["22222",700,800,900]],columns=["zip_code","factory","warehouse", "retail"])
print(fasla.head())
print(fasla.columns)
# Out:
#   zip_code  factory  warehouse  retail
# 0    00000      100        200     300
# 1    11111      400        500     600
# 2    22222      700        800     900
# Index(['zip_code', 'factory', 'warehouse', 'retail'], dtype='object')

# %%
melted_fasla=fasla.melt(id_vars="zip_code",value_name='distance',var_name='location')
melted_fasla
# Out:
#   zip_code   location  distance
# 0    00000    factory       100
# 1    11111    factory       400
# 2    22222    factory       700
# 3    00000  warehouse       200
# 4    11111  warehouse       500
# 5    22222  warehouse       800
# 6    00000     retail       300
# 7    11111     retail       600
# 8    22222     retail       900

# %%
sns.barplot(x="zip_code", y="distance", hue="location",data=melted_fasla)
# Out:
# <Axes: xlabel='zip_code', ylabel='distance'>

# %%
phool=sns.load_dataset("iris")
phool.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
phool.to_excel('../day_2/phool1.xlsx')

# %%
df=sns.load_dataset("titanic")
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.describe().T
# Out:
#           count       mean        std   min      25%      50%   75%       max
# survived  891.0   0.383838   0.486592  0.00   0.0000   0.0000   1.0    1.0000
# pclass    891.0   2.308642   0.836071  1.00   2.0000   3.0000   3.0    3.0000
# age       714.0  29.699118  14.526497  0.42  20.1250  28.0000  38.0   80.0000
# sibsp     891.0   0.523008   1.102743  0.00   0.0000   0.0000   1.0    8.0000
# parch     891.0   0.381594   0.806057  0.00   0.0000   0.0000   0.0    6.0000
# fare      891.0  32.204208  49.693429  0.00   7.9104  14.4542  31.0  512.3292

# %%
df["survived"].describe()
# Out:
# count    891.000000
# mean       0.383838
# std        0.486592
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# Name: survived, dtype: float64

# %%
df.groupby(["sex","survived","who","pclass"])["survived"].count()
# Out:
# sex     survived  who    pclass
# female  0         child  1           1
#                          3          14
#                   woman  1           2
#                          2           6
#                          3          58
#         1         child  1           2
#                          2          10
#                          3          16
#                   woman  1          89
#                          2          60
#                          3          56
# male    0         child  3          19
#                   man    1          77
#                          2          91
#                          3         281
#         1         child  1           3
#                          2           9
#                          3           9
#                   man    1          42
#                          2           8
#                          3          38
# Name: survived, dtype: int64

# %%
print(df.columns)
sns.countplot(x="survived", hue="embark_town", data=df)
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')
# <Axes: xlabel='survived', ylabel='count'>

# %%
sns.boxplot(x="survived",y="sex" ,data=df)
# Out:
# <Axes: xlabel='survived', ylabel='sex'>

# %%
print(df.columns)
print(df.head(2))
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False

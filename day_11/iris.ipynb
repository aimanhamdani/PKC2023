# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=sns.load_dataset('iris')

# %%
df.shape
# Out:
# (150, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
# df["species"]= df["species"].astype("category")

# %%
# df["species_code"]=df["species"].cat.codes

# %%
# df.drop("species",axis=1,inplace=True)

# %%
# print(f"quartile = \n{df.quantile([0.25,0.50,0.75])}")
# print(f"mean = \n{df.mean()}")
# print(f"median = \n{df.median()}")

# %%
# print(f"mean = {df['sepal_length'].mean()}")
# print(f"manually calculate average = {df['sepal_length'].sum()/df['sepal_length'].count()}")
# print(f"median = {df['sepal_length'].median()}")
# print(f"mode = {df['sepal_length'].mode()}")

# %%
# df.var()

# %%
# df.std()

# %%
# df["extra"]= np.nan
# df.info()

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df["species_cat"]=df["species"].astype("category")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
#  5   species_cat   150 non-null    category
# dtypes: category(1), float64(4), object(1)
# memory usage: 6.3+ KB

# %%
df=df.drop("species",axis=1)

# %%
df["species_code"]=df["species_cat"].cat.codes

# %%
df=df.drop("species_cat",axis=True)

# %%
corr=df.corr()

# %%
corr
# Out:
#               sepal_length  sepal_width  petal_length  petal_width  \
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000
# species_code      0.782561    -0.426658      0.949035     0.956547
#
#               species_code
# sepal_length      0.782561
# sepal_width      -0.426658
# petal_length      0.949035
# petal_width       0.956547
# species_code      1.000000

# %%
plt.figure(figsize=(10,5))
sns.heatmap(corr)
plt.title("HEATMAP OF CORRELATION BETWEEN FEATURES")
# Out:
# Text(0.5, 1.0, 'HEATMAP OF CORRELATION BETWEEN FEATURES')

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species_code'],
#       dtype='object')

# %%
sns.violinplot(data=df, x='sepal_length', y='sepal_width',hue="species_code")
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
kashti=sns.load_dataset("titanic")

# %%
g=sns.FacetGrid(kashti,hue="survived",col="pclass",margin_titles=True, palette={1:"seagreen", 0:"grey"})
g=g.map(plt.scatter,"fare","age", edgecolor="b") .add_legend();

# %%
sns.violinplot(df)
# Out:
# <Axes: >

# %%
df1=sns.load_dataset("iris")

# %%
df1.hist()
# Out:
# array([[<Axes: title={'center': 'sepal_length'}>,
#         <Axes: title={'center': 'sepal_width'}>],
#        [<Axes: title={'center': 'petal_length'}>,
#         <Axes: title={'center': 'petal_width'}>]], dtype=object)

# %%
sns.boxenplot(df1)
# Out:
# <Axes: >

# %%
df1.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
sns.scatterplot(df1)
# Out:
# <Axes: >

# %%
sns.barplot(data=df1)
# Out:
# <Axes: >

# %%
sns.FacetGrid(df1, hue ="species",  
              height = 6).map(plt.scatter,  
                              'sepal_length',  
                              'petal_length').add_legend()
